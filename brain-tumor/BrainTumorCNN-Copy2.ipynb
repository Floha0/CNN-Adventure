# %% [markdown]
# # Furkan Gülhan
# # Import Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from seaborn import histplot

from sklearn.metrics import f1_score, accuracy_score, roc_auc_score

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
from torchvision import transforms
from torch.utils.data import Dataset, TensorDataset, DataLoader

import os
from PIL import Image

# %% [markdown]
# ## Directions
# Directionları giriyorum. İlk başlarda dataseti import ederken hata aldığım için izinleri kontrol ediyorum.
# 2. train_dir'in sebebi kodu daha hızlı çalıştırmak ve bug fix aşamasını daha hızlı yapmak için dataseti ayırmam. orijinal olan dataset 'original' klasörü altında.

# %%
train_dir = os.path.join(os.getcwd(), 'train')
train_dir = os.path.join(train_dir, 'original')
images_dir = os.path.join(train_dir, 'images')
labels_dir = os.path.join(train_dir, 'labels')
print(os.access(images_dir, os.R_OK))  # Check read permission
print(os.access(images_dir, os.W_OK))  # Check write permission
print(os.access(images_dir, os.X_OK))  # Check execute permission
# Out:
# True
# True
# True

# %% [markdown]
# ## Karşılıksız Dosyaları Silme

# %%
labels = set(file.split('.')[0] for file in os.listdir(labels_dir))
images = set(file.split('.')[0] for file in os.listdir(images_dir))

for file in images - labels:
    os.remove(os.path.join(images_dir, file + '.jpg'))

# %% [markdown]
# # Dataset Import Class
# image'lerin hepsi jpg ile bittiği için diğer uzantıları eklemedim.
#
# getitem'da image'leri siyah-beyaz olarak istedim. Label'larda ise ilk değeri aldım. batch için unsqueeze ile ekstra dimension ekledim. ileride squeeze kullanacağım. Örnek olarak:
# > label = 1
# > 1. int(1) -> 1
# > 2. torch.tensor(1, dtype=torch.float32) -> tensor(1.0)
# > 3. tensor(1.0).unsqueeze(0) -> tensor([1.0]) (shape (1,))
#
# Olası hata durumlarını ayıklamak için try except ile düzeltmelerimi yaptım. Başta dediğim gibi directionlardan kaynaklanan sorunlar aldım, izinleri kontrol etmek işe yaradı.

# %%
class BrainTumorDataset(Dataset):
    def __init__(self, images_dir, labels_dir, transform = None):
        self.images_dir = images_dir
        self.labels_dir = labels_dir
        self.transform = transform
        
        self.image_filenames = sorted([os.path.splitext(f)[0] for f in os.listdir(images_dir) if f.lower().endswith(('.jpg'))])
    def __len__(self):
        return len(self.image_filenames)
    def __getitem__(self, idx):
        img_name = self.image_filenames[idx]
        image_path = os.path.join(self.images_dir, img_name + '.jpg')
        label_path = os.path.join(self.labels_dir, img_name + '.txt')

        try:
            image = Image.open(image_path)
            image = image.convert('L') # ensure black and white
            
            with open(label_path, 'r') as f:
                label = int(f.read().strip()[0])  # Convert '0'/'1' to integer
            label = torch.tensor(int(label), dtype=torch.float32).unsqueeze(0)


            if self.transform:
                image = self.transform(image)

            return image, label
        except FileNotFoundError:
            print(f"Warning: Image or label file not found for {img_name}. Skipping.")
            return self.__getitem__((idx + 1) % len(self)) # Return the next item (handles edge cases)
        except Exception as e: # Catch other potential issues
            print(f"Error loading image or label for {img_name}: {e}. Skipping.")
            return self.__getitem__((idx + 1) % len(self)) # Return the next item (handles edge cases)

# %% [markdown]
# ## Load Dataset
# Transformation'ları tanımladım.
# > **Resize** ile image'lerin büyüklüğünden emin oldum,
#
# > **ToTensor** ile **pytorcha** entegre ettim,
#
# > Normalize kısmında ise veriyi belirli bir aralığa yerleştirdip öğrenmesini kolaylaştırdım. Araştırdığım kadarıyla **siyah-beyaz** resim olduğu için **0.5** parametreleri optimal olan fakat eğer ki **RGB** kullanıyor olsaydım hazır **ResNet**, **ImageNet** gibi büyük veri setlerinden gelen yaygın parametreleri kullanıcaktım, örnek olarak **ImageNet** için şu parametreler: (mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#
# Batch ayarlarını yaptım ve train_loader ile uygun hale getirdim.

# %%
# Define transformations
data_transforms = transforms.Compose([
    transforms.Resize((512, 512)),  # Ensure correct size
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

dataset = BrainTumorDataset(images_dir, labels_dir, transform=data_transforms)

batch_size = 32
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Accessing data:
for i in range(len(dataset)):
    image, label = dataset[i]
    print(f"Image shape: {image.shape}, Label: {label}")
# Out:
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])

# %% [markdown]
# ## Sample image
# Dataseti düzgün import ettim mi kontrol etmek için örnek bir image yazdırdım.

# %%
_image, _label = dataset[0]  # Get first image
_image = np.squeeze(_image)  # Remove the extra dimension, shape becomes (512, 512)
plt.imshow(_image, cmap='gray')
plt.show()

# %% [markdown]
# ## Label Distribution
# Dataset'teki labelların dağılışını görmek için görselleştiriyorum.
#
# Modeli geliştirme aşamasında bir yerde hata almıştım, internette arama yaparak muhtemel nedenlerden birinin dataset'teki labelların eşit dağılmamasından kaynaklanabileceğini öğrendim. Bu işlem bunun neden olmadığını, hatanın başka bir nedeni olduğunu görmemi sağladı.

# %%
_labels_np = torch.tensor([label for _, label in dataset]).numpy()
plt.figure(figsize=(6, 4))

# Histogram visualization to see frequency distribution
plt.hist(_labels_np, bins=10, color='skyblue', edgecolor='black')
plt.xlabel("Value Range")
plt.ylabel("Frequency")

# Show plot
plt.show()

# %% [markdown]
# ## CNN Class
# nöron sayısını arttırınca **acc** değerim arttı fakat **f1** skorum önemli ölçüde azaldığı için nöron sayısını bu şekil bırakıyorum. Örnek olması açısından:
# >Layerlarda sırasıyla; ***1,8,32,128,1*** nöronla işlem yapınca **acc** skorum **0.7**'lere kadar çıktı fakat **f1** skorum daha **acc**'nin yavaş yükselişine rağmen hızlı bir şekilde **0.2**'lere kadar düştü.
# >
# > Başka bir örnekte ise layer'lardaki nöron sayıları hafif farklı (daha yavaş geçişli) ve **loss** yine aynı değerlerde iken **0.5**-**0.6** aralığında **acc** ve **f1** değerleri aldım.
#
# Şu anki modeli tercih etme sebebim ise daha başarılı modellerde başarı oranında en fazla neredeyse 0.05'lik bir artış olmasına karşılık eğitim hızının oldukça fazla artması dolayısıyla o modelleri verimli görmemem.

# %%
class SimpleCNN(nn.Module):
    def __init__(self): # Will not add in channels parameter, assuming black and white which only has 1 channel
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=8, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.pool = nn.MaxPool2d(kernel_size=(2,2), stride=(2,2))
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=(3,3), stride=(1,1), padding=(1,1))

        # 16 out channels, 128x128 remaining res.
        self.fc1 = nn.Linear(16 * 128 * 128, 128)  
        self.fc2 = nn.Linear(128, 1)  # Output layer for binary classification
        
    def forward(self, x):
        x = nn.ReLU()(self.conv1(x)) # First step
        x = self.pool(x)
        
        x = nn.ReLU()(self.conv2(x)) # Second step
        x = self.pool(x)
        
        x = x.view(-1, 16 * 128 * 128)  # Flatten
        # safer alternatives:
        # x = x.view(x.shape[0], -1)
        # x = x.reshape(x.shape[0], -1)
        
        x = nn.ReLU()(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))  # Sigmoid for binary classification
        return x

# %%
model = SimpleCNN()

# %% [markdown]
# ## Loss and Optimizer
# Loss fonksiyonu olarak **Binary Cross Entropy**'i kullandım. Modelin son aşamasında sigmoid kullanmıyor olsaydım ***BCEWithLogitLoss*** (yanlış yazmış olabilirim) kullanıcaktım.
#
# Optimizer olarak ise binary classification modellerinde Adam'ı daha başarılı buluyorum ve learning rate ile yaptığım oynamalar sonucu şuanki değerin iyi olduğunu düşünüyorum.

# %%
# Cross-Entropy Loss Function
criterion  = nn.BCELoss()

# %%
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Train Loop
# Epoch sayısı olarak loss'u olabildiğince düşürmek için 100'ü uygun gördüm her ne kadar ağır bir işlem olsa da. Gördüğüm en düşük loss değeri şuanki.
# > Epoch = 100, loss = 0.0001
#
# Diğer işlemleri commentlar ile açıkladım zaten,

# %%
num_epochs = 100
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
loss_values = []
for epoch in range(num_epochs):
    model.train()
    total_loss = 0  # Track total loss for averaging

    for images, labels in train_loader:  # Use DataLoader instead of raw dataset
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images).squeeze(1)  # Forward pass
        labels = labels.view(-1)  # Ensure labels have shape [batch_size]
        
        loss = criterion(outputs, labels)  # Compute loss
        
        optimizer.zero_grad()  # Clear previous gradients
        loss.backward()  # Backpropagation (compute gradients)
        optimizer.step()  # Update weights
        
        total_loss += loss.item()

    # Print average loss per epoch
    print("outputs:     ", outputs[:5])  # Print first 5 predictions
    print("labels:      ", labels[:5])  # Print first 5 actual labels
    avg_loss = total_loss / len(train_loader)
    loss_values.append(avg_loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}')
# Out:
# outputs:      tensor([0.5966, 0.6208, 0.5820, 0.6024, 0.5979], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 0., 0.], device='cuda:0')
# Epoch [1/100], Loss: 0.8550
# outputs:      tensor([0.5299, 0.4705, 0.5612, 0.5207, 0.5361], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 1., 1.], device='cuda:0')
# Epoch [2/100], Loss: 0.6782
# outputs:      tensor([0.5383, 0.6708, 0.6453, 0.4928, 0.8108], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 0., 0., 0.], device='cuda:0')
# Epoch [3/100], Loss: 0.6782
# outputs:      tensor([0.5326, 0.6593, 0.3668, 0.4030, 0.6178], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 0., 0., 1.], device='cuda:0')
# Epoch [4/100], Loss: 0.6491
# outputs:      tensor([0.5703, 0.6056, 0.5226, 0.6295, 0.4232], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 1., 1.], device='cuda:0')
# Epoch [5/100], Loss: 0.6442
# outputs:      tensor([0.4849, 0.2733, 0.5596, 0.4976, 0.2856], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 1., 1., 0.], device='cuda:0')
# Epoch [6/100], Loss: 0.6085
# outputs:      tensor([0.4811, 0.4391, 0.8301, 0.8038, 0.4119], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 1., 1., 0.], device='cuda:0')
# Epoch [7/100], Loss: 0.5923
# outputs:      tensor([0.3954, 0.4441, 0.3681, 0.5806, 0.5179], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 0., 1., 1.], device='cuda:0')
# Epoch [8/100], Loss: 0.5490
# outputs:      tensor([0.3670, 0.6892, 0.8266, 0.8778, 0.4667], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 1., 0.], device='cuda:0')
# Epoch [9/100], Loss: 0.5120
# outputs:      tensor([0.4408, 0.9433, 0.7436, 0.4389, 0.7911], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 0., 1.], device='cuda:0')
# Epoch [10/100], Loss: 0.4752
# outputs:      tensor([0.6344, 0.6289, 0.3149, 0.7846, 0.4369], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 0., 1., 0.], device='cuda:0')
# Epoch [11/100], Loss: 0.4732
# outputs:      tensor([0.5885, 0.9462, 0.7478, 0.2985, 0.5361], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 0., 1.], device='cuda:0')
# Epoch [12/100], Loss: 0.4356
# outputs:      tensor([0.6202, 0.4270, 0.3007, 0.3012, 0.5110], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 0., 0., 0.], device='cuda:0')
# Epoch [13/100], Loss: 0.3911
# outputs:      tensor([0.9827, 0.2177, 0.5486, 0.4569, 0.3204], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 0., 0.], device='cuda:0')
# Epoch [14/100], Loss: 0.3500
# outputs:      tensor([0.3307, 0.3393, 0.2113, 0.5869, 0.4302], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 0., 0., 0.], device='cuda:0')
# Epoch [15/100], Loss: 0.3168
# outputs:      tensor([0.8632, 0.8993, 0.7424, 0.3183, 0.7939], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 1., 1.], device='cuda:0')
# Epoch [16/100], Loss: 0.3081
# outputs:      tensor([0.9212, 0.9457, 0.9208, 0.6539, 0.5866], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 1., 1.], device='cuda:0')
# Epoch [17/100], Loss: 0.2738
# outputs:      tensor([0.0030, 0.7734, 0.9130, 0.8937, 0.8326], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 1., 1.], device='cuda:0')
# Epoch [18/100], Loss: 0.2695
# outputs:      tensor([0.1081, 0.9917, 0.4695, 0.9784, 0.8212], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 0., 1., 1.], device='cuda:0')
# Epoch [19/100], Loss: 0.2607
# outputs:      tensor([0.3825, 0.9612, 0.8710, 0.9165, 0.0085], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 1., 0.], device='cuda:0')
# Epoch [20/100], Loss: 0.2072
# outputs:      tensor([0.9538, 0.8559, 0.9829, 0.2632, 0.4690], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 0., 0.], device='cuda:0')
# Epoch [21/100], Loss: 0.1837
# outputs:      tensor([0.7846, 0.9969, 0.9628, 0.7593, 0.1550], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 1., 0.], device='cuda:0')
# Epoch [22/100], Loss: 0.1594
# outputs:      tensor([0.0723, 0.0603, 0.8988, 0.6727, 0.0275], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 1., 1., 0.], device='cuda:0')
# Epoch [23/100], Loss: 0.1453
# outputs:      tensor([0.0042, 0.0126, 0.9866, 0.9645, 0.1984], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 1., 1., 1.], device='cuda:0')
# Epoch [24/100], Loss: 0.1284
# outputs:      tensor([9.7590e-01, 7.7625e-02, 6.3217e-01, 1.7535e-04, 8.2146e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 0., 1.], device='cuda:0')
# Epoch [25/100], Loss: 0.1112
# outputs:      tensor([0.0013, 0.8804, 0.9773, 0.9958, 0.9816], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 1., 1.], device='cuda:0')
# Epoch [26/100], Loss: 0.0979
# outputs:      tensor([0.0033, 0.0044, 0.9026, 0.1397, 0.1435], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 1., 0., 0.], device='cuda:0')
# Epoch [27/100], Loss: 0.0944
# outputs:      tensor([0.9376, 0.9794, 0.3030, 0.0028, 0.9486], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 0., 0., 1.], device='cuda:0')
# Epoch [28/100], Loss: 0.0781
# outputs:      tensor([2.1703e-02, 9.4812e-01, 4.7599e-05, 9.9909e-01, 9.2335e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 0., 1., 1.], device='cuda:0')
# Epoch [29/100], Loss: 0.0750
# outputs:      tensor([9.6697e-01, 1.6887e-02, 9.8779e-04, 9.9977e-01, 9.9389e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 0., 1., 1.], device='cuda:0')
# Epoch [30/100], Loss: 0.0665
# outputs:      tensor([1.1619e-04, 6.8008e-02, 1.4277e-03, 9.9452e-01, 9.8727e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 0., 1., 1.], device='cuda:0')
# Epoch [31/100], Loss: 0.0592
# outputs:      tensor([0.0036, 0.0036, 0.9259, 0.1682, 0.9360], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 1., 0., 1.], device='cuda:0')
# Epoch [32/100], Loss: 0.0537
# outputs:      tensor([0.8393, 0.0072, 0.9969, 0.9924, 0.0025], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 1., 0.], device='cuda:0')
# Epoch [33/100], Loss: 0.0418
# outputs:      tensor([2.0317e-01, 1.0000e+00, 9.9929e-01, 2.2069e-04, 9.8323e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 0., 1.], device='cuda:0')
# Epoch [34/100], Loss: 0.0366
# outputs:      tensor([0.9905, 0.9904, 0.9926, 0.9106, 0.9751], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 1., 1.], device='cuda:0')
# Epoch [35/100], Loss: 0.0319
# outputs:      tensor([8.8025e-01, 6.4037e-04, 1.9672e-02, 5.4122e-03, 1.9805e-03],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 0., 0., 0.], device='cuda:0')
# Epoch [36/100], Loss: 0.0305
# outputs:      tensor([8.8083e-02, 9.9705e-01, 1.3233e-04, 9.6181e-01, 1.6473e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 0., 1., 0.], device='cuda:0')
# Epoch [37/100], Loss: 0.0272
# outputs:      tensor([0.0903, 0.0402, 0.9802, 0.0213, 0.9728], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 1., 0., 1.], device='cuda:0')
# Epoch [38/100], Loss: 0.0242
# outputs:      tensor([0.9909, 0.0048, 0.8541, 0.9996, 0.0238], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 1., 0.], device='cuda:0')
# Epoch [39/100], Loss: 0.0256
# outputs:      tensor([1.0000e+00, 4.7563e-07, 5.4802e-02, 9.8663e-01, 1.3161e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 0., 1., 0.], device='cuda:0')
# Epoch [40/100], Loss: 0.0211
# outputs:      tensor([9.9849e-01, 1.1105e-04, 9.9987e-01, 9.5214e-07, 3.9239e-03],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 0., 0.], device='cuda:0')
# Epoch [41/100], Loss: 0.0211
# outputs:      tensor([5.1868e-05, 2.1300e-02, 2.0277e-02, 9.9990e-01, 2.0573e-02],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 0., 1., 0.], device='cuda:0')
# Epoch [42/100], Loss: 0.0164
# outputs:      tensor([0.0043, 1.0000, 0.9902, 0.0018, 0.9886], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 0., 1.], device='cuda:0')
# Epoch [43/100], Loss: 0.0155
# outputs:      tensor([0.9920, 0.9998, 0.9979, 0.0034, 0.9990], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 0., 1.], device='cuda:0')
# Epoch [44/100], Loss: 0.0134
# outputs:      tensor([9.9364e-01, 9.9452e-01, 1.9511e-04, 6.2237e-04, 9.9999e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 0., 0., 1.], device='cuda:0')
# Epoch [45/100], Loss: 0.0132
# outputs:      tensor([0.9870, 0.0012, 0.9998, 0.0018, 1.0000], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 0., 1.], device='cuda:0')
# Epoch [46/100], Loss: 0.0110
# outputs:      tensor([5.1984e-02, 9.6212e-01, 1.9823e-04, 7.0207e-02, 9.6187e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 0., 0., 1.], device='cuda:0')
# Epoch [47/100], Loss: 0.0107
# outputs:      tensor([0.0160, 0.0013, 0.0102, 0.9940, 0.9996], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 0., 1., 1.], device='cuda:0')
# Epoch [48/100], Loss: 0.0094
# outputs:      tensor([4.1477e-05, 9.8149e-01, 9.9852e-01, 1.2543e-04, 1.1739e-04],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 0., 0.], device='cuda:0')
# Epoch [49/100], Loss: 0.0088
# outputs:      tensor([9.9983e-01, 9.0645e-06, 9.9988e-01, 1.0000e+00, 9.9999e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 1., 1.], device='cuda:0')
# Epoch [50/100], Loss: 0.0080
# outputs:      tensor([9.9988e-01, 5.1353e-05, 3.9541e-08, 5.5914e-02, 9.9999e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 0., 0., 1.], device='cuda:0')
# Epoch [51/100], Loss: 0.0074
# outputs:      tensor([9.9950e-01, 9.9944e-01, 2.5271e-09, 9.9870e-01, 9.9990e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 0., 1., 1.], device='cuda:0')
# Epoch [52/100], Loss: 0.0068
# outputs:      tensor([2.3051e-09, 9.9904e-01, 9.9340e-01, 1.0000e+00, 1.0872e-03],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 1., 0.], device='cuda:0')
# Epoch [53/100], Loss: 0.0067
# outputs:      tensor([1.0000, 0.9999, 0.9867, 0.0020, 0.9998], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 0., 1.], device='cuda:0')
# Epoch [54/100], Loss: 0.0059
# outputs:      tensor([1.0000, 0.9966, 1.0000, 1.0000, 1.0000], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 1., 1.], device='cuda:0')
# Epoch [55/100], Loss: 0.0056
# outputs:      tensor([9.9981e-01, 1.0000e+00, 9.9971e-01, 1.8175e-02, 1.3975e-16],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 0., 0.], device='cuda:0')
# Epoch [56/100], Loss: 0.0054
# outputs:      tensor([0.0186, 0.0485, 0.0015, 0.0041, 0.0031], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 0., 0., 0.], device='cuda:0')
# Epoch [57/100], Loss: 0.0050
# outputs:      tensor([9.9975e-01, 6.2281e-09, 9.9616e-01, 9.9270e-01, 9.9862e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 1., 1.], device='cuda:0')
# Epoch [58/100], Loss: 0.0045
# outputs:      tensor([5.5903e-11, 1.2937e-02, 4.7166e-03, 9.9974e-01, 1.1138e-03],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 0., 1., 0.], device='cuda:0')
# Epoch [59/100], Loss: 0.0043
# outputs:      tensor([9.9985e-01, 9.8173e-01, 9.9976e-01, 2.1192e-10, 9.9876e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 0., 1.], device='cuda:0')
# Epoch [60/100], Loss: 0.0042
# outputs:      tensor([1.5695e-05, 9.9984e-01, 9.9560e-01, 9.9690e-01, 9.9734e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 1., 1.], device='cuda:0')
# Epoch [61/100], Loss: 0.0038
# outputs:      tensor([9.9525e-01, 9.9947e-01, 1.6271e-03, 7.1080e-12, 9.8381e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 0., 0., 1.], device='cuda:0')
# Epoch [62/100], Loss: 0.0037
# outputs:      tensor([9.9969e-01, 1.6584e-02, 1.4965e-04, 9.8765e-01, 7.3142e-03],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 0., 1., 0.], device='cuda:0')
# Epoch [63/100], Loss: 0.0034
# outputs:      tensor([9.9945e-01, 3.3712e-07, 1.0000e+00, 8.8464e-05, 9.9998e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 0., 1.], device='cuda:0')
# Epoch [64/100], Loss: 0.0034
# outputs:      tensor([7.4500e-05, 9.9677e-01, 9.9983e-01, 9.9380e-01, 9.9578e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 1., 1.], device='cuda:0')
# Epoch [65/100], Loss: 0.0031
# outputs:      tensor([1.6130e-03, 2.6289e-03, 1.0000e+00, 2.8598e-04, 9.9998e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 1., 0., 1.], device='cuda:0')
# Epoch [66/100], Loss: 0.0029
# outputs:      tensor([9.0514e-03, 1.4915e-04, 9.9939e-01, 9.6329e-01, 1.9304e-02],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 1., 1., 0.], device='cuda:0')
# Epoch [67/100], Loss: 0.0028
# outputs:      tensor([0.0014, 0.0017, 0.9861, 1.0000, 1.0000], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 1., 1., 1.], device='cuda:0')
# Epoch [68/100], Loss: 0.0026
# outputs:      tensor([9.9999e-01, 4.8907e-04, 9.9580e-01, 1.9598e-04, 1.1549e-03],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 0., 0.], device='cuda:0')
# Epoch [69/100], Loss: 0.0025
# outputs:      tensor([1.2297e-06, 9.9958e-01, 7.9131e-04, 5.6124e-04, 1.1337e-02],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 0., 0., 0.], device='cuda:0')
# Epoch [70/100], Loss: 0.0025
# outputs:      tensor([1.7324e-03, 9.9953e-01, 3.0702e-08, 4.9298e-18, 2.2918e-02],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 0., 0., 0.], device='cuda:0')
# Epoch [71/100], Loss: 0.0026
# outputs:      tensor([2.3677e-02, 9.9986e-01, 4.3434e-03, 5.6309e-05, 8.5494e-06],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 0., 0., 0.], device='cuda:0')
# Epoch [72/100], Loss: 0.0023
# outputs:      tensor([1.0000e+00, 9.9939e-01, 9.9988e-01, 1.0000e+00, 5.1728e-08],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 1., 0.], device='cuda:0')
# Epoch [73/100], Loss: 0.0020
# outputs:      tensor([9.9851e-01, 9.9988e-01, 1.0000e+00, 9.9028e-01, 5.9483e-07],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 1., 0.], device='cuda:0')
# Epoch [74/100], Loss: 0.0021
# outputs:      tensor([9.9450e-01, 1.7669e-03, 3.2419e-07, 9.9983e-01, 3.3001e-04],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 0., 1., 0.], device='cuda:0')
# Epoch [75/100], Loss: 0.0019
# outputs:      tensor([1.1555e-04, 9.9989e-01, 9.9915e-01, 4.5931e-07, 9.9826e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 0., 1.], device='cuda:0')
# Epoch [76/100], Loss: 0.0017
# outputs:      tensor([9.9562e-01, 1.9725e-03, 2.4236e-06, 7.9772e-03, 9.9982e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 0., 0., 1.], device='cuda:0')
# Epoch [77/100], Loss: 0.0017
# outputs:      tensor([5.2496e-04, 1.2414e-03, 1.7169e-03, 1.9440e-03, 1.0000e+00],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 0., 0., 1.], device='cuda:0')
# Epoch [78/100], Loss: 0.0017
# outputs:      tensor([8.0630e-13, 1.1221e-08, 1.5150e-03, 1.0000e+00, 4.4968e-03],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 0., 1., 0.], device='cuda:0')
# Epoch [79/100], Loss: 0.0016
# outputs:      tensor([5.9424e-06, 1.0000e+00, 1.1163e-06, 9.9999e-01, 9.9913e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 0., 1., 1.], device='cuda:0')
# Epoch [80/100], Loss: 0.0015
# outputs:      tensor([2.5341e-03, 2.2325e-03, 9.9897e-01, 9.8561e-01, 1.9091e-04],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 1., 1., 0.], device='cuda:0')
# Epoch [81/100], Loss: 0.0015
# outputs:      tensor([1.0000e+00, 9.9888e-01, 2.9834e-05, 9.9863e-01, 9.9981e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 0., 1., 1.], device='cuda:0')
# Epoch [82/100], Loss: 0.0014
# outputs:      tensor([1.0000e+00, 9.9989e-01, 2.0713e-09, 2.7116e-03, 1.0000e+00],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 0., 0., 1.], device='cuda:0')
# Epoch [83/100], Loss: 0.0013
# outputs:      tensor([9.9825e-01, 9.9995e-01, 1.0000e+00, 2.0589e-04, 1.0000e+00],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 0., 1.], device='cuda:0')
# Epoch [84/100], Loss: 0.0013
# outputs:      tensor([9.9987e-01, 9.9940e-01, 5.1353e-05, 7.1055e-04, 1.4275e-03],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 0., 0., 0.], device='cuda:0')
# Epoch [85/100], Loss: 0.0012
# outputs:      tensor([1.0000e+00, 9.9998e-01, 1.6735e-03, 1.0000e+00, 3.4689e-09],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 0., 1., 0.], device='cuda:0')
# Epoch [86/100], Loss: 0.0012
# outputs:      tensor([9.9469e-01, 9.9890e-01, 1.4583e-06, 1.6143e-05, 6.5083e-05],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 0., 0., 0.], device='cuda:0')
# Epoch [87/100], Loss: 0.0011
# outputs:      tensor([7.9630e-12, 3.0467e-04, 1.5425e-03, 2.1587e-04, 9.9988e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 0., 0., 1.], device='cuda:0')
# Epoch [88/100], Loss: 0.0011
# outputs:      tensor([9.9892e-01, 9.3685e-04, 9.9992e-01, 1.9344e-20, 9.9900e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 0., 1.], device='cuda:0')
# Epoch [89/100], Loss: 0.0011
# outputs:      tensor([7.6715e-03, 1.0000e+00, 1.3173e-03, 4.1952e-08, 9.9999e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 0., 0., 1.], device='cuda:0')
# Epoch [90/100], Loss: 0.0010
# outputs:      tensor([9.9989e-01, 1.0000e+00, 9.9999e-01, 9.9915e-01, 2.2141e-04],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 1., 1., 0.], device='cuda:0')
# Epoch [91/100], Loss: 0.0010
# outputs:      tensor([1.0000e+00, 9.9959e-01, 1.2330e-04, 5.3690e-04, 1.1975e-03],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 0., 0., 0.], device='cuda:0')
# Epoch [92/100], Loss: 0.0009
# outputs:      tensor([9.9942e-01, 1.0000e+00, 3.6319e-03, 1.3661e-07, 4.2181e-03],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 1., 0., 0., 0.], device='cuda:0')
# Epoch [93/100], Loss: 0.0009
# outputs:      tensor([1.0000e+00, 1.5672e-04, 1.0000e+00, 9.9924e-01, 2.5460e-03],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 1., 0.], device='cuda:0')
# Epoch [94/100], Loss: 0.0009
# outputs:      tensor([2.3192e-04, 1.7765e-12, 9.9861e-01, 1.6823e-07, 9.9916e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 1., 0., 1.], device='cuda:0')
# Epoch [95/100], Loss: 0.0008
# outputs:      tensor([1.0000e+00, 2.8197e-04, 9.9916e-01, 1.0000e+00, 7.3032e-04],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 1., 0.], device='cuda:0')
# Epoch [96/100], Loss: 0.0008
# outputs:      tensor([9.9957e-01, 1.0110e-04, 3.7173e-04, 9.9865e-01, 3.9855e-05],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 0., 1., 0.], device='cuda:0')
# Epoch [97/100], Loss: 0.0008
# outputs:      tensor([9.9886e-01, 2.1132e-04, 1.0000e+00, 9.9992e-01, 9.9581e-01],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([1., 0., 1., 1., 1.], device='cuda:0')
# Epoch [98/100], Loss: 0.0008
# outputs:      tensor([2.9441e-04, 1.7423e-03, 3.5698e-05, 9.9831e-01, 8.5727e-10],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 0., 0., 1., 0.], device='cuda:0')
# Epoch [99/100], Loss: 0.0008
# outputs:      tensor([1.6638e-03, 9.9920e-01, 9.9871e-01, 9.9998e-01, 4.0626e-04],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# labels:       tensor([0., 1., 1., 1., 0.], device='cuda:0')
# Epoch [100/100], Loss: 0.0008

# %% [markdown]
# ## Loss Curve
# Aşırı gerekli olmasa da gözümden kaçma ihtimaline karşılık bir curve çizmek istedim. Bir de bazı yerlerde dalgalandığını gördüm, bu benim için yeni bir araştırma konusu oldu.

# %%
plt.plot(loss_values)  # Store loss per epoch in loss_values list
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss Curve")
plt.show()

# %% [markdown]
# # Test Dataset

# %%
test_dir = os.path.join(os.getcwd(), 'valid')
test_images_dir = os.path.join(test_dir, 'images')
test_labels_dir = os.path.join(test_dir, 'labels')
print(os.access(test_images_dir, os.R_OK))  # Check read permission
print(os.access(test_images_dir, os.W_OK))  # Check write permission
print(os.access(test_images_dir, os.X_OK))  # Check execute permission
# Out:
# True
# True
# True

# %%
test_dataset = BrainTumorDataset(test_images_dir, test_labels_dir, transform=data_transforms)

batch_size = 32
test_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Accessing data:
for i in range(len(test_dataset)):
    image, label = test_dataset[i]
    print(f"Image shape: {image.shape}, Label: {label}")

test_labels = set(file.split('.')[0] for file in os.listdir(test_labels_dir))
test_images = set(file.split('.')[0] for file in os.listdir(test_images_dir))

for file in test_images - test_labels:
    os.remove(os.path.join(test_images_dir, file + '.jpg'))
# Out:
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([1.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])
# Image shape: torch.Size([1, 512, 512]), Label: tensor([0.])

# %% [markdown]
# ## Threshold, f1 ve acc
# *threshold*'u **0.1** arttırarak *acc* ve *f1* skorlarına baktım.
# en iyi *acc* değerinde **(0.6099)** *f1* skoru **0.5584**. *acc* ve *f1*'ın birlikte en iyi olduğunu düşündüğüm değer şuanki *threshold* **(0.54)**
# Şuanki değerlerim *acc* = **0.5874**, *f1* = **0.5741**
#
# Değerler şuanki run'da farklı olabilir fakat bahsettiğim değerlere yakın olmalı.
#
# ## Auc-Roc Score
# **Auc-Roc** score ile derinlemesine rapor tutamadım. Windowsumda sıkıntı olduğu için **cuda** indiremiyorum ve bütün işlemleri **cpu** ile hallediyorum bu da yavaş çalışmama sebep oluyor. **acc** ve **f1** dengesini tutarken bile zorlandım o denkleme **Auc-Roc** eklersem işin içinden çıkamazdım. O yüzden böyle bırakıyorum. Şuanki **Auc-Roc** değerim **0.5850**

# %%
def binary_classification_metrics(model, dataloader, device):
    model.eval()  # Set model to evaluation mode
    all_preds = []
    all_labels = []
    all_probs = []
    
    with torch.no_grad():  # No need to compute gradients for evaluation
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)

            # Get predictions from CNN
            outputs = model(images)  # Forward pass through the CNN

            # Apply sigmoid to logits and threshold to get binary predictions
            probs = torch.sigmoid(outputs).squeeze()  # Apply sigmoid to get probabilities
            preds = (probs > 0.54).float()  # Thresholding at 0.5 for binary classification
            #print(probs.cpu().numpy())

            all_preds.append(preds.cpu().numpy())  # Move to CPU and append to list
            all_labels.append(labels.cpu().numpy())  # Same for labels
            all_probs.append(probs.cpu().numpy())

    # Calculate accuracy and F1 score
    accuracy = accuracy_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)
    auc_roc = roc_auc_score(all_labels, all_probs)

    return accuracy, f1, auc_roc
accuracy, f1, auc_roc = binary_classification_metrics(model, test_dataset, device)
print(f'Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}, Auc-Roc Score: {auc_roc:.4f}')
# Out:
# Accuracy: 0.5740, F1 Score: 0.5498, Auc-Roc Score: 0.5850
