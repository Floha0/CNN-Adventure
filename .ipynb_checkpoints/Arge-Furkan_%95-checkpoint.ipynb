# %% [raw]
# ### Import
# Gerekli Kütüphaneleri import ediyorum.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import StandardScaler  
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init

# %% [markdown]
# ## Database
# Database'i import ediyorum

# %%
df = pd.read_csv("Dos_detection_dataset.csv")
#df = df.round(4)
df.head()
# Out:
#    traffic_flow  throughput  bandwidth  bandwidth_deviation  end_to_end_delay  \
# 0    437.086107  133.309818  33.553512             0.067270          2.902780
# 1    955.642876  293.855426  32.228092             0.079668          4.046618
# 2    758.794548  442.825626  91.562912             0.025047          3.824789
# 3    638.792636  379.501199  32.459158             0.062487          0.854110
# 4    240.416776  412.952517  34.475475             0.057175          0.831322
#
#    mean_latency  energy_consumption  packet_loss  generalized_entropy  \
# 0      0.227136           35.930278     0.007760             0.661531
# 1      0.263046           16.895454     0.037355             0.054153
# 2      0.434546           44.895783     0.166249             0.291761
# 3      0.203002           34.524650     0.153354             0.432811
# 4      0.441342           16.288155     0.070129             0.870116
#
#         gid  projected_entropy  label
# 0  0.038811           0.913578      0
# 1  0.037491           0.525360      0
# 2  0.013830           0.724910      0
# 3  0.046903           0.436048      0
# 4  0.032739           0.630035      0

# %% [markdown]
# ### Boş değer
# Olası hataları önlemek amaçlı boş değer var mı kontrol ediyorum.

# %%
# Checking Missing values
missing_values = df.isnull().sum()
print("found" if missing_values.any() else "not found")
# Out:
# not found

# %% [markdown]
# ### Seperate
# Variable'lara ayırıyorum.
# train ve test variableları ayrı olucak. oran şuanlık 80-20

# %%
#x = [df[col].tolist() for col in df.columns if col != "label"]
#x = list(zip(*x))  # or use np.array(x).T.tolist()
# Separate features and labels
x = df.drop(columns=["label"]).values
#x = df["traffic_flow"].values
y = df["label"].values

# Split into training and testing sets (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8)
print("Shapes:", len(x_train), len(y_train), len(x_test), len(y_test))
# Out:
# Shapes: 800 800 200 200

# %%
x_test
# Out:
# array([[4.53200597e+02, 2.52403092e+02, 9.92195111e+01, ...,
#         6.43718995e-01, 2.56436898e-02, 6.86366607e-01],
#        [5.45659219e+02, 4.05825424e+02, 6.05100509e+01, ...,
#         5.39882480e-01, 2.07310408e-02, 3.16292349e-01],
#        [6.73686911e+02, 2.93583351e+02, 3.64139941e+01, ...,
#         3.92131556e-01, 1.85941843e-02, 5.05165712e-01],
#        ...,
#        [1.84998665e+02, 4.34473292e+02, 7.23243544e+01, ...,
#         9.24975923e-01, 2.58755757e-02, 5.00645271e-02],
#        [1.28064822e+02, 1.84426508e+02, 4.45919535e+01, ...,
#         9.78593221e-01, 2.71841097e-02, 4.43253441e-01],
#        [8.26696140e+02, 4.49936636e+02, 8.23243182e+01, ...,
#         2.10606307e-01, 2.15994957e-02, 8.89130536e-01]])

# %% [markdown]
# ### Normalization
# uçuk değerleri engellemek için değerleri 0 ve 1 etrafına çekiyorum.

# %%
#x_train = x_train.reshape(-1, 1)
#x_test = x_test.reshape(-1, 1)

scaler = StandardScaler()  
x_train = scaler.fit_transform(x_train)  
x_test = scaler.transform(x_test)# Create a plot

plt.figure(figsize=(10, 5))

# Histogram visualization to see frequency distribution
plt.hist(x_train.ravel(), bins=100, color='skyblue', edgecolor='black')
plt.title("Number Distribution from 0 to 1000")
plt.xlabel("Value Range")
plt.ylabel("Frequency")

# Show plot
plt.show()

# %%
x_train
# Out:
# array([[ 0.79807956, -0.48184912,  0.31097792, ..., -0.78869813,
#          0.22189476, -0.4676968 ],
#        [ 1.09777466,  0.6364265 , -1.38034083, ..., -1.1068743 ,
#         -0.51182662, -0.67021156],
#        [ 1.02815222,  0.93460384, -0.24412567, ..., -1.03259503,
#          0.83080795,  0.31776272],
#        ...,
#        [-1.55259935, -1.72236371,  0.59790216, ...,  1.48861531,
#         -0.17721363, -0.80709022],
#        [ 0.48722122, -1.30279397,  0.40680957, ..., -0.46325426,
#         -1.28221891,  0.48742695],
#        [ 0.548113  ,  1.6355807 ,  0.01022034, ..., -0.52661092,
#         -0.22636235,  0.14615745]])

# %%
from sklearn.decomposition import PCA

# Reducing to 2 dimensions using PCA
pca = PCA(n_components=2)
x_train_pca = pca.fit_transform(x_train)

# Scatter plot of the 2 principal components
plt.figure(figsize=(10, 10))
plt.scatter(x_train_pca[:, 0], x_train_pca[:, 1], alpha=0.5)
plt.title("PCA of Standardized x_train")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Datasetin Pytorch'a entegrasyonu
# Elimdeki verileri pytorch ile uyumlu hale getiriyorum.

# %%
x_train = torch.tensor(x_train, dtype=torch.float32)
x_test = torch.tensor(x_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)  # Reshape to (N,1)
y_test = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)  # Reshape to (N,1)

# %% [markdown]
# # Model
# ### Layers
# 3 layer; 1 input, 2 hidden layer.
# * fc1: Input layer, 11 nöron
# * fc2: Hidden layer 1, 16 nöron
# * fc3: Hidden layer 2, 8 nöron
#
# ### Forward Passing
# Output hariç tüm adımları ReLU fonksiyonu ile sağladım. Output olarak 0-1 aralığı lazım olduğu için son fonksiyon sigmoid.
# ```Dead neuron var ise leaky ReLU'ya çevirebilirim```

# %%
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(11, 180)
        self.bn1 = nn.BatchNorm1d(180)
        self.dropout1 = nn.Dropout(0.2)

        self.fc2 = nn.Linear(180, 180)
        self.bn2 = nn.BatchNorm1d(180)
        self.dropout2 = nn.Dropout(0.2)

        self.fc3 = nn.Linear(180, 1)
        
        # Use LeakyReLU instead of ReLU to prevent dead neurons
        self.activation = nn.LeakyReLU(negative_slope=0.01)
        
    def forward(self, x):
        x = self.activation(self.bn1(self.fc1(x)))
        x = self.dropout1(x)

        x = self.activation(self.bn2(self.fc2(x)))
        x = self.dropout2(x)

        x = self.fc3(x)
        x = torch.sigmoid(x)
        
        return x

# %%
model = SimpleNN()

# %% [markdown]
# ### Cost Function
# Cost function olarak ***Binary Classification*** yağtığım için **Binary Cross-Entropy** fonksiyonunu kullanacağım.

# %%
# Binary Cross-Entropy Cost Function
criterion  = nn.BCELoss()

# %%
optimizer = optim.Adam(model.parameters(), lr=0.01)
#optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# ### Dataseti ayırma
# Önce labela göre bir ayrım yapıyorum.
# x: input, y: output | olacak şekilde
# Sonrasonda train ve test olmak üzere 2'ye ayırıyorum. Oranlama olarak %80'e %20 yaptım şimdilik.

# %%
num_epochs = 100
for epoch in range(num_epochs):
    optimizer.zero_grad()   # Clear previous gradients
    outputs = model(x_train)  # Forward pass
    
    loss = criterion(outputs, y_train)  # Compute loss
    loss.backward()  # Backpropagation (compute gradients)
    optimizer.step()  # Update weights

    if (epoch + 1) % 10 == 0:  # Print every 10 epochs
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [10/100], Loss: 0.5483
# Epoch [20/100], Loss: 0.4871
# Epoch [30/100], Loss: 0.4485
# Epoch [40/100], Loss: 0.3728
# Epoch [50/100], Loss: 0.3332
# Epoch [60/100], Loss: 0.2752
# Epoch [70/100], Loss: 0.2304
# Epoch [80/100], Loss: 0.2283
# Epoch [90/100], Loss: 0.1856
# Epoch [100/100], Loss: 0.1660

# %% [raw]
# y_pred = model(x_train)

# %% [raw]
# y_pred_np = y_pred.detach().cpu().numpy()
# plt.hist(y_pred_np, bins=100, color='skyblue', edgecolor='black')
# plt.title("Number Distribution from 0 to 1")
# plt.xlabel("Value Range")
# plt.ylabel("Frequency")
#
# # Show plot
# plt.show()

# %% [raw]
# # Apply Min-Max normalization to scale the data to [0, 1]
# scaler = MinMaxScaler(feature_range=(0, 1))
# normalized_pred_np = scaler.fit_transform(y_pred_np)
#
# plt.hist(normalized_data, bins=100, color='skyblue', edgecolor='black')
# plt.show()

# %% [raw]
# tmp = np.where(normalized_data > 0.5, 1, 0)
# y_train_np = y_train.detach().cpu().numpy()
# y_train_np = y_train_np.round()
# y_train_list = y_train_np.tolist()
#
# acc = (tmp == y_train_np).mean()
# print(f"Training acc: {acc.item() * 100:.2f}%")
#
# plt.hist(tmp, bins=100, color='skyblue', edgecolor='black')
# plt.show()
# plt.hist(y_train_np, bins=100, color='skyblue', edgecolor='black')
# plt.show()

# %% [raw]
# acc = (normalized_data == y_train_np).mean()
# print(f"Training acc: {acc.item() * 100:.2f}%")

# %% [raw]
# y_pred.mean().item()

# %% [raw]
# y_pred[:10]

# %%
threshold = 0.5
with torch.no_grad():  # Disable gradient computation for evaluation
    y_pred_train = model(x_train)
    rounded_y_pred_train = (y_pred_train > threshold).float()  # Convert probabilities to 0/1 labels
    train_accuracy = (rounded_y_pred_train == y_train).float().mean()
    print(f"Training Accuracy: {train_accuracy.item() * 100:.2f}%")
    

    y_pred_test = model(x_test)
    rounded_y_pred_test = (y_pred_test > threshold).float()
    validation_accuracy = (rounded_y_pred_test == y_test).float().mean()
    print(f"Validation Accuracy: {validation_accuracy.item() * 100:.2f}%")
    
    y_pred_test_np = rounded_y_pred_train.cpu().numpy()
    y_test_np = y_train.cpu().numpy()

    f1 = f1_score(y_test_np, y_pred_test_np)
    print(f"F1-Score: {f1:.4f}")
    
    print("Class 0 count:", (y_pred_test_np == 0).sum())
    print("Class 1 count:", (y_pred_test_np == 1).sum())
# Out:
# Training Accuracy: 95.88%
# Validation Accuracy: 62.50%
# F1-Score: 0.9314
# Class 0 count: 564
# Class 1 count: 236

# %%
plt.figure(figsize=(3, 3))
plt.hist(y_pred_train, bins=35, color='skyblue', edgecolor='black')
plt.show()

plt.figure(figsize=(3, 3))
plt.hist(y_train, bins=35, color='skyblue', edgecolor='black')
plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.hist(y_pred_test, bins=35, color='skyblue', edgecolor='black')
plt.show()

plt.figure(figsize=(3, 3))
plt.hist(y_test, bins=35, color='skyblue', edgecolor='black')
plt.show()

# %%
for i in range(25):
    print(y_pred_test[i],"--",y_test[i])
# Out:
# tensor([0.1546]) -- tensor([1.])
# tensor([0.9079]) -- tensor([0.])
# tensor([0.0899]) -- tensor([1.])
# tensor([0.9280]) -- tensor([1.])
# tensor([0.0341]) -- tensor([0.])
# tensor([0.0087]) -- tensor([0.])
# tensor([0.0884]) -- tensor([1.])
# tensor([0.0042]) -- tensor([1.])
# tensor([0.6411]) -- tensor([0.])
# tensor([9.5004e-05]) -- tensor([0.])
# tensor([0.0051]) -- tensor([0.])
# tensor([0.0004]) -- tensor([1.])
# tensor([0.0062]) -- tensor([0.])
# tensor([0.3677]) -- tensor([0.])
# tensor([0.0181]) -- tensor([0.])
# tensor([0.2160]) -- tensor([0.])
# tensor([0.0122]) -- tensor([0.])
# tensor([0.9870]) -- tensor([0.])
# tensor([0.0028]) -- tensor([0.])
# tensor([0.5116]) -- tensor([0.])
# tensor([0.9854]) -- tensor([1.])
# tensor([0.0119]) -- tensor([1.])
# tensor([0.0317]) -- tensor([1.])
# tensor([0.0276]) -- tensor([0.])
# tensor([0.0196]) -- tensor([0.])

# %%
# Apply Min-Max normalization to scale the data to [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
normalized_pred_np = scaler.fit_transform(y_pred_test.cpu().numpy())

plt.hist(normalized_pred_np, bins=100, color='skyblue', edgecolor='black')
plt.title("Number Distribution from 0 to 1")
plt.show()

plt.hist(y_pred_test.cpu().numpy(), bins=100, color='skyblue', edgecolor='black')
plt.title("Number Distribution from 0 to 1")
plt.show()

threshold = 0.3
rounded_normalized_pred_np = (normalized_pred_np >= threshold).astype(int)

normalized_accuracy = (rounded_normalized_pred_np == y_test).float().mean()
print(f"Validation Accuracy: {normalized_accuracy.item() * 100:.2f}%")

f1 = f1_score(y_test_np, rounded_normalized_pred_np)
print(f"F1-Score: {f1:.4f}")
# Out:
# Validation Accuracy: 56.00%
# F1-Score: 0.2787
